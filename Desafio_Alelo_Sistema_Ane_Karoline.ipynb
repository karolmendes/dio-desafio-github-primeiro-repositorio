# %% [markdown]
# <a href="https://colab.research.google.com/github/karolmendes/dio-desafio-github-primeiro-repositorio/blob/main/Desafio_Alelo_Sistema_Ane_Karoline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SISTEMA DE PERGUNTAS E RESPOSTAS 

print()
print('Olá human@! Agora que você analisou os dados, vamos ver o que você compreendeu\n')
print('Abaixo aparecerão questões sobre as Olimpíadas de Tóquio. Digite a alternativa correta e tecle ENTER. Boa Sorte!')


perguntas = {
    
    'Pergunta 1': {
        'pergunta': 'Qual o total de atletas que participaram das Olimpíadas de 2021?',
        'respostas': {'a.': '11.085','b.': '10.930','c.': '12.123'},
        'resposta_certa': 'a',
    },
    
    'Pergunta 2': {
        'pergunta': 'Qual o total de atletas, do sexo masculino, que participaram do evento olímpico?',
        'respostas': {'a.': '5.800','b.': '5.804','c.': '6.236'},
        'resposta_certa': 'b',
    },

    'Pergunta 3': {
        'pergunta': 'Qual o total de atletas, do sexo feminino, que participaram do evento olímpico?',
        'respostas': {'a.': '5.432','b.': '5.999','c.': '6.130'},
        'resposta_certa': 'a',
    },
  
    'Pergunta 4': {
        'pergunta': 'Qual o país que ganhou mais medalhas de ouro nas Olimpíadas de Tóquio?',
        'respostas': {'a.': 'EUA','b.': 'CHI','c.': 'RUS'},
        'resposta_certa': 'a',
    },

    'Pergunta 5': {
        'pergunta': 'Qual o país que ganhou mais medalhas de prata nas Olimpíadas de Tóquio',
        'respostas': {'a.': 'CHI','b.': 'EUA','c.': 'JAP'},
        'resposta_certa': 'b',
    },

    'Pergunta 6': {
        'pergunta': 'Qual o país que ganhou mais medalhas de bronze nas Olimpíadas de Tóquio',
        'respostas': {'a.': 'CHI','b.': 'EUA','c.': 'ALE'},
        'resposta_certa': 'b',
    },

    'Pergunta 7': {
        'pergunta': 'Qual o país que tem mais medalhas em seu quadro geral?',
        'respostas': {'a.': 'EUA','b.': 'CHI','c.': 'JAP'},
        'resposta_certa': 'c',
    },

    'Pergunta 8': {
        'pergunta': 'Quantos treinadores estavam nas Olimpíadas de Tóquio',
        'respostas': {'a.': '392','b.': '394','c.': '399'},
        'resposta_certa': 'b',
    },

    'Pergunta 9': {
        'pergunta': 'Qual dos esportes tem mais participantes do sexo femino, do que masculino',
        'respostas': {'a.': 'BMX Freestyle','b.': 'Equitação','c.': 'Judô'},
        'resposta_certa': 'a',
    },
}

print()

respostas_certas = 0
for pk, pv in perguntas.items():
  print(f'{pk}: {pv["pergunta"]}')

  print('Respostas: ')

  for rk, rv in pv['respostas'].items():
    print(f'{rk}: {rv}')

  resposta_usuario = input('Digite aqui sua resposta: ')
  
  if resposta_usuario == pv['resposta_certa']:
    print('Você acertou!')
    respostas_certas +=1
  else:
    print('Você errou!')

  print()

  print(f'Você acertou {respostas_certas} questões!')
# Out:
# Olá human@! Agora que você analisou os dados, vamos ver o que você compreendeu
#
# Abaixo aparecerão questões sobre as Olimpíadas de Tóquio. Digite a alternativa correta e tecle ENTER. Boa Sorte!
#
# Pergunta 1: Qual o total de atletas que participaram das Olimpíadas de 2021?
# Respostas:
# a.: 11.085
# b.: 10.930
# c.: 12.123
# Digite aqui sua resposta: a
# Você acertou!
#
# Você acertou 1 questões
# Pergunta 2: Qual o total de atletas, do sexo masculino, que participaram do evento olímpico?
# Respostas:
# a.: 5.800
# b.: 5.804
# c.: 6.236
# Digite aqui sua resposta: a
# Você errou!
#
# Você acertou 1 questões
# Pergunta 3: Qual o total de atletas, do sexo feminino, que participaram do evento olímpico?
# Respostas:
# a.: 5.432
# b.: 5.999
# c.: 6.130
# Digite aqui sua resposta: a
# Você acertou!
#
# Você acertou 2 questões
# Pergunta 4: Qual o país que ganhou mais medalhas de ouro nas Olimpíadas de Tóquio?
# Respostas:
# a.: EUA
# b.: CHI
# c.: RUS
# Digite aqui sua resposta: a
# ...
